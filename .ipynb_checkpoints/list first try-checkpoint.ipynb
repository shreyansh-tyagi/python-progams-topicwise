# %%
5+5
# Out:
# 10

# %%
a=12
b=10
c=a+b
print(c)
# Out:
# 22

# %%
a=[1,2,3]
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 3

# %%
a=list(input('enter the value : ')
b=len(a)
#print(b)
#c=[]
for i in range(b):
    a.sort()
    ord(a[i])
print(a)
#print(c)
# Out:
#   File "<ipython-input-16-359936024746>", line 2
#     b=len(a)
#     ^
# SyntaxError: invalid syntax
