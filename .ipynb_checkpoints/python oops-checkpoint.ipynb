# %% [markdown]
# # object-oriented-programming(oops)

# %% [markdown]
# ## class and object :-

# %%
class Phone: # a class should always start with a class keyword and the first letter of 
             #class should capital
    def make_call(self): #functionality of class 
        print('making a call')
    def play_games(self):
        print('playing games')
p=Phone() #creating object or instanciating the object 
p.make_call() #invoking the object
p.play_games()
# Out:
# making a call
# playing games

# %%
class Phone:
    def set_color(self,color):
        self.color=color
    def set_cost(self,cost):
        self.cost=cost
    def get_color(self):
        return self.color
    def get_cost(self):
        return self.cost
    def make_call(self):
        print('making call')
    def play_games(self):
        print('playing games')
p1=Phone()
p1.set_color('blue')
p1.set_cost(200)
p1.get_color()
p1.get_cost()
p1.make_call()
p1.play_games()
# Out:
# making call
# playing games

# %%
class Runnow:
    def setcost(self,cost):
        self.cost=cost
        return self.cost
class Next:    
    def setcolor(self,color):
        self.color=color
        return self.color
r=Runnow()
n=Next()
r.setcost('blue')
n.setcolor(100)
# Out:
# 100

# %%
class Employee:
    pass
emp1=Employee()
emp2=Employee()
print(emp1)
print(emp2)
emp1.name='shrey'
emp1.lastname='tyagi'
emp1.salary=10000
emp2.name='aryan'
emp2.lastname='tyagi'
emp2.salary=10000
print(emp1.salary)
print(emp1.name)
print(emp1.lastname)
print(emp2.name)
# Out:
# <__main__.Employee object at 0x7fae5011f710>
# <__main__.Employee object at 0x7fae5011f750>
# 10000
# shrey
# tyagi
# aryan

# %%
# class with object and constructor
class Employee:
    def __init__(self,first,last,pay):
        self.fname=first
        self.last=last
        self.pay=pay
        self.email=first+'.'+last+'@'+'gmail.com'
emp1=Employee('corey','edward',20000)
a=input('enter your first name: ')
b=input('enter your last name: ')
c=int(input('enter your salary: '))
emp2=Employee(a,b,c)
print(emp1)
print(emp1.email)
print(emp1.fname)
print(emp2.fname)
print(emp2.last)
print(emp2.email)
# Out:
# enter your first name: shrey
# enter your last name: tyagi
# enter your salary: 20000
# <__main__.Employee object at 0x7fae50138f50>
# corey.edward@gmail.com
# corey
# shrey
# tyagi
# shrey.tyagi@gmail.com

# %%
class Employee:  #class
    def __init__(self,first,last,pay): #constructor
        self.fname=first
        self.last=last
        self.pay=pay
        self.email=first+'.'+last+'@'+'gmail.com'
    def fullname(self): #function inside class 
         print(f'fisrt name: {self.fname} last name: {self.last} with salary {self.pay}\
         and email {self.email}')
emp1=Employee('corey','edward',20000) #instantiating object or creating object
#and passing value to constructor which should be in same order
a=input('enter your first name: ')
b=input('enter your last name: ')
c=int(input('enter your  salary: '))
emp2=Employee(a,b,c) #another object taking input from user 
# instantiating object or creating object but with some input
print(emp1.fullname()) #invoking object1 
print(emp2.fullname()) #invoking object 2 , here need to pass the argument inside
Employee.fullname(emp2) # but here while calling the member of class using the 
#class name an instance name should be passed
# Out:
# enter your first name: shrey
# enter your last name: tyagi
# enter your  salary: 3000
# fisrt name: corey last name: edward with salary 20000         and email corey.edward@gmail.com
# None
# fisrt name: shrey last name: tyagi with salary 3000         and email shrey.tyagi@gmail.com
# None
# fisrt name: shrey last name: tyagi with salary 3000         and email shrey.tyagi@gmail.com

# %%
class Student:
    def __init__(self,name,age,grade):
        self.name=name
        self.age=age
        self.grade=grade
    def deco(text):
        print('decorator started')
        def innerdeco(*args,**kwargs):
            print('inner decorator started')
            text(*args,**kwargs)
            print('inner decorator ended')
    @deco
    def calldeco(name,age,grade):
        print(name)
    name=input('enter your name: ')
    age=int(input('enter your age: '))
    grade=int(input('enter your grade: '))
    calldeco(name,age,grade)    
obj1=Employee.calldeco(name,age,grade)
obj1.deco()
# Out:
# decorator started
# enter your name: dsdf
# enter your age: 123
# enter your grade: 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-41914c6c88eb> in <module>
# ----> 1 class Student:
#       2     def __init__(self,name,age,grade):
#       3         self.name=name
#       4         self.age=age
#       5         self.grade=grade
#
# <ipython-input-9-41914c6c88eb> in Student()
#      16     age=int(input('enter your age: '))
#      17     grade=int(input('enter your grade: '))
# ---> 18     calldeco(name,age,grade)
#      19 #obj1=Employee.calldeco(name,age,grade)
#      20 #obj1.deco()
#
# TypeError: 'NoneType' object is not callable

# %%
class Student:
    def __init__(self,name,age,grade):
        self.name=name
        self.age=age
        self.grade=grade
    def get_std(self):
        return self.grade
class Course:
    def __init__(self,course,max_student):
        self.course=course
        self.maxs=max_student
        self.student=[]
    def std_details(self,student):
        if len(self.student)<self.maxs:
            self.student.append(student)
            print(self.student)
            print('true')
        print('false')
    def avg(self):
        value=0
        for i in self.student:
            value+=i.get_std()
        return value/len(self.student)
s1=Student('shrey',21,85)
s2=Student('mani',22,75)
s3=Student('manu',22,70)
c1=Course('science',2)
c1.std_details(s1)
c1.std_details(s2)
c1.std_details(s3)
print(c1.avg())
print(s1.get_std())
print(s2.get_std())
# Out:
# [<__main__.Student object at 0x7fa62c5345d0>]
# true
# false
# [<__main__.Student object at 0x7fa62c5345d0>, <__main__.Student object at 0x7fa62c534590>]
# true
# false
# false
# 80.0
# 85
# 75

# %%
class Student:
    def __init__(self,name,age,grade):
        self.name=name
        self.age=age
        self.grade=grade
    def getgrade(self):
        return self.grade
class Course:
    def __init__(self,course_name,max_student):
        self.course_name=course_name
        self.max_student=max_student
        self.student=[]
    def printdetails(self):
        return f'course: {self.course_name}'
    def studentdetails(self,student):
        if len(self.student)<self.max_student:
            self.student.append(student)
            print('data inserted in list')
        else:
            print(f'data out of range {self.max_student}')
    def getaverage(self):
        value=0
        for i in self.student:
            value+=i.getgrade()
        print(f'total marks of students')
