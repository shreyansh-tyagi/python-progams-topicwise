# %% [markdown]
# # function

# %%
#pass by value
a=10
def fun_name(b):
    print('value of b: ',b)
    print('id of a: ',id(b))
    b=100
    print('id of b: ',id(b))
    print('new value of b: ',b)
fun_name(a)
# Out:
# value of b:  10
# id of a:  94188532118560
# id of b:  94188532121440
# new value of b:  100

# %%
#pass by reference
a=[10,20,30]
print('id of a: ',id(a))
def fun_name(b):
    print('fisrt list: ',b)
    print('id of a: ',{id(b)})
    b[0]=99
    b[1]=21
    print('id of b: ',{id(b)})
    print('second list: ',b)
fun_name(a)
# Out:
# id of a:  140186127288352
# fisrt list:  [10, 20, 30]
# id of a:  {140186127288352}
# id of b:  {140186127288352}
# second list:  [99, 21, 30]

# %%
def fun1(x,y):
    print('x:',x)
    print('y:',y)
fun1(20,10)
# Out:
# x: 20
# y: 10

# %%
#keyword argument
def student(firstname,lastname):
    print(firstname,lastname)
student(firstname='geeksforgeeks',lastname='practice')
student(lastname='practice',firstname='geeksforgeeks')
# Out:
# geeksforgeeks practice
# geeksforgeeks practice

# %%
def fun1 (normal):
    for i in normal:
        print(i)
lst=[1,2,3,'hello','world',4,5,8]
fun1(lst)
# Out:
# 1
# 2
# 3
# hello
# world
# 4
# 5
# 8

# %%
lst=[1,2,3,'hello','value',4,5]
print(type(lst))
fun1(lst)
print(type(lst))
def fun1 (normal):
    normal[0]=31
    normal[1]=41
    for i in normal:
        print(i)
# Out:
# <class 'list'>
# 31
# 41
# 3
# hello
# value
# 4
# 5
# <class 'list'>

# %%
#normal function
def abc(a,b,c,d):
    print(a,b,c,d)
abc('hello','world','s','t')
# Out:
# hello world s t

# %%
def abc(a,b,c,d):
    print(a,b,c,d)
s=1
x=2
y=4
z=3
abc(s,x,y,z)
# Out:
# 1 2 4 3

# %%
#*args(non-keyword argument)
def abc(*shrey):
    print(shrey)
    print(type(shrey))
abc('hello','wrld','s','t','w')
print(type(abc))
# Out:
# ('hello', 'wrld', 's', 't', 'w')
# <class 'tuple'>
# <class 'function'>

# %%
def abc(*shrey):
    print(shrey)
    print(type(shrey))
s=[1,2,3,'shreyansh','s','t',1,2]
print(type(s))
abc(s)
# Out:
# <class 'list'>
# ([1, 2, 3, 'shreyansh', 's', 't', 1, 2],)
# <class 'tuple'>

# %%
# *args(non keyword argument) is always in tuple form, hence tuple are immutable in nature therefore it is
#impossible to insert the value inside tuple
def abc(*abc):
    #abc[0]='hello' 
    #abc[1]='function' it is tuple therefore no assignment can be done
    for i in abc:
        print(i,end='__')
a=(1,2,3,'d','sd',3.04,56,'shrey',22,'st')
abc(*a)
abc(a)
# Out:
# 1__2__3__d__sd__3.04__56__shrey__22__st__(1, 2, 3, 'd', 'sd', 3.04, 56, 'shrey', 22, 'st')__

# %%
a=('a','c',1,3)
#a[0]=21
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# ('a', 'c', 1, 3)

# %%
#normal and * args argument
def abc(normal,*argsy):
    print(normal)
    print('\n\nthis is args:' )
    print(type(argsy))
    for i in argsy:
        print(i)
        print(type(i))
      #  print(len(i))
  #  for y in x:
  #      print(y)
   #     print(type(y))
    #    print(len(i))
normal='this is normal statement'
x=[1,2,3,'shrey','s',30.04]
abc(normal,*x)
print()
print(type(abc))
# Out:
# this is normal statement
#
#
# this is args:
# <class 'tuple'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# 3
# <class 'int'>
# shrey
# <class 'str'>
# s
# <class 'str'>
# 30.04
# <class 'float'>
#
# <class 'function'>

# %%
# **kwargs(keyword argument)
def abc (**shrey):
    print(shrey)
x={'name':'shreyansh','class':'mca','age':22}    
abc(**x)
# Out:
# {'name': 'shreyansh', 'class': 'mca', 'age': 22}

# %%
def abc (**shrey):
    for key,value in shrey.items():  #this is the syntax to define **kwargs in for loop
        print(f'{key} is {value}')
        print({key},{value})
       # print(key,value)
    
x={'name':'shreyansh','class':'mca','age':22}    
abc(**x)
# Out:
# name is shreyansh
# {'name'} {'shreyansh'}
# class is mca
# {'class'} {'mca'}
# age is 22
# {'age'} {22}

# %%
# yield keyword that is used in generator concept 
def bc():
    yield 1
    yield 2
    yield 3
    print(bc)
    print(__next(bc))
bc()
# Out:
# <generator object bc at 0x7f3e80624050>

# %%
def bc():
    yield 1
    yield 2
    yield 3
   # print(bc)
    #print(__next(bc))
for value in bc():  #function call bc() in for loop
    print(value)
# Out:
# 1
# 2
# 3

# %%
def bc():
    yield 1
    yield 2
    yield 3
    print(bc)
bc()
# Out:
# <generator object bc at 0x7fa2082ef550>

# %%
def abc():
    i=1; #initializing i with 1
    while True: #infinite loop
        yield i*i #generator
        i+=1
for x in abc():
    if(x>100):
        break
    print(x)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
def bc():
    yield 1
    yield 2
    yield 3
x=bc()
print(x.__next__()) # double underscore is used along with next function with paranthesis= __next__()
print(x.__next__())
print(x.__next__()) 
#print(x.__next__()) it will give message of stop iteration
print('\n')
for a in bc(): #here for loop automatically will stop the iteration
    print(a)
# Out:
# 1
# 2
# 3
#
#
# 1
# 2
# 3

# %%
#fibonacci series using generator
def fib(limit):
    a,b=0,1
    while a<limit:    
        yield a
        a,b=b,a+b
x=fib(5)
print(x)

print(x.__next__())
print(x.__next__())
print(x.__next__())
print(x.__next__())
print(x.__next__())
#print(x.__next__()) #show stop iteration 
# now by using for in loop
print('by using for loop: ')
for a in fib(10):
    print(a)
# Out:
# <generator object fib at 0x7f6230fb6dd0>
# 0
# 1
# 1
# 2
# 3
# by using for loop:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
# lambda function
str1="hello world"
print(lambda str1:str1)
# Out:
# <function <lambda> at 0x7f238c598290>

# %%
x='geeksforgeeks'
lambda x: x
print(x)
# Out:
# geeksforgeeks

# %%
x='geeksforgeeks'
(lambda x: print(x))(x)
# Out:
# geeksforgeeks

# %%
x=lambda a,b,c: a+b+c
y=lambda a,b,c: a*b*c

print('sum: ',x(1,2,3),'\nmultiplty: ',y(2,2,2))
# Out:
# sum:  6
# multiplty:  8

# %%
a=int(input('enter the value of a: '))
b=int(input('enter the value of b: '))
c=int(input('enter the value of c: '))
x=lambda a,b,c: a+b+c
y=lambda a,b,c: a*b*c

print('sum: ',x(a,b,c),'\nmultiplty: ',y(a,b,c))
# Out:
# enter the value of a: 1
# enter the value of b: 3
# enter the value of c: 2
# sum:  6
# multiplty:  6

# %%
#normal function
x=int(input('enter the value for square: '))
def abc(a):
    return a*a
print('normal fuunction')
print(abc(x)) 
#lambda function
y=lambda a:a*a
print('lambda function')
print(y(x))
# Out:
# enter the value for square: 4
# normal fuunction
# 16
# lambda function
# 16

# %%
def abc(n):
    return lambda a: a**n #it will return a**2 back to the function call and store in variable x
x=abc(2)
print(x(5)) # this is the lambda function call in which we pass the 5 as a value to variable a
# Out:
# 25

# %%
x=lambda a: a*a
a=x(5) #lambda function call
print(a)
# Out:
# 25

# %%
# filter function
a=[100,20,30,3,7,8,9,10,21,75,76]
x=filter(lambda b: b%2==0, a )
y=map(lambda b:b%2==0,a)
print(list(x))
print(list(y))
# Out:
# [100, 20, 30, 8, 10, 76]
# [True, True, True, False, False, True, False, True, False, False, True]

# %%
#map function

a=[100,20,30,3,7,8,9,10,21,75,76]
y=map(lambda b:b%2==0,a)
z=filter(lambda c:c%2==0,a)
print(tuple(y))
print(list(z))
# Out:
# (True, True, True, False, False, True, False, True, False, False, True)
# [100, 20, 30, 8, 10, 76]

# %%
#to count word in string
# for example:- kiet is good institute
