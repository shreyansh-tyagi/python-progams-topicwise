# %%
with open('text.txt','r') as f:
    print(f.read())
# Out:
# Python is a general purpose language, used by data scientists and developers, which makes it easy to collaborate across your organization through its simple syntax. People choose to use Python so that they can communicate with other people. The other reason is rooted in academic research and statistical models. i am shreyansh tyagi trying to connect this file with my read and only file

# %%
with open('text.txt','r') as f:
    print(f.read())
# Out:
# Python is a general purpose language, used by data scientists and developers, which makes it easy to collaborate across your organization through its simple syntax. People choose to use Python so that they can communicate with other people. The other reason is rooted in academic research and statistical models. i am shreyansh tyagi trying to connect this file with my read and only file

# %%
with open('text.txt','r') as f:
    print(f.readlines())
# Out:
# ['Python is a general purpose language, used by data scientists and developers, which makes it easy to collaborate across your organization through its simple syntax. People choose to use Python so that they can communicate with other people. The other reason is rooted in academic research and statistical models. i am shreyansh tyagi trying to connect this file with my read and only file\n']

# %%
with open('text.txt','r') as f:
    for i in f:
        print(i,end='')
# Out:
# Python is a general purpose language, used by data scientists and developers, which makes it easy to collaborate across your organization through its simple syntax. People choose to use Python so that they can communicate with other people. The other reason is rooted in academic research and statistical models. i am shreyansh tyagi trying to connect this file with my read and only file

# %%
with open('text.txt','r') as f:
    for i in f:
        print(i)
# Out:
# Python is a general purpose language, used by data scientists and developers, which makes it easy to collaborate across your organization through its simple syntax. People choose to use Python so that they can communicate with other people. The other reason is rooted in academic research and statistical models. i am shreyansh tyagi trying to connect this file with my read and only file

# %%
with open('text.txt','r') as g: #text.txt is the file name of my text file 
    print(g.read(100))
    print(g.read(100))
# Out:
# Python is a general purpose language, used by data scientists and developers, which makes it easy to
#  collaborate across your organization through its simple syntax. People choose to use Python so that

# %%
with open('myfile.txt','r') as hello:
    print(hello.read())
# Out:
# Our program will provide you with significant career growth by making you an
# exceptional Data Science professional. The program builds expertise in real-world
# statistical & mathematical concepts, predictive modeling and machine
# learning techniques using data and in-depth understanding
# of the latest Data Science tools.
#
# so this myfile of type text and i am trying to link this file from read and write only file

# %%
with open('myfile.txt','r') as hello:
    print(hello.read(10))
    print(hello.read(10))
    print(hello.read(5))
    print(hello.tell()) #it will tell that we are working on this index right now
# Out:
# Our progra
# m will pro
# vide
# 25

# %%
with open('myfile2.txt','w') as w:
    w.write('hi, trying to write the file and creating new file as this file \
    does not exist so lets see what happen let me add some lines to see whether it get added to my created\
    file also')

# %%
with open('myfile2.txt','r') as r:
    print(r.read())
# Out:
# hi, trying to write the file and creating new file as this file     does not exist so lets see what happen let me add some lines to see whether it get added to my created    file also

# %%
with open('myfile.txt','r') as read_file:
    with open('myfile2.txt','w') as write_file:
        write_file.write(read_file.read()) #in write file i have written the text

# %%
with open('IMG-20200514-WA0006.jpg','r') as r:
    print(r.read()) #will show utf 8 error
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-21-c92bf94f3116> in <module>
#       1 with open('IMG-20200514-WA0006.jpg','r') as r:
# ----> 2     print(r.read())
#
# ~/anaconda3/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
with open('IMG-20200514-WA0006.jpg','rb') as r:
    print(r.read()) # adding b so as to read the binary of that number
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\x01\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\xff\xc2\x00\x11\x08\x05\x00\x03\xc0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x002\n\x94\x01(\xcbP\x80\x02\xa0\xb2\x88\x00\x12\xd2\x10\xa9D\xa2\x04\x14\x94P"\x92*\xa2\x88\x00\x12\x88\x00*P\x00\x12\x88\x00\x00X(\x00\x00\x00\x88\xb0\x02(\x8a\x04\x00\x02\x81,(\x16\x0be[,"\xc1e\x12\x
# ...

# %%
with open('IMG-20200514-WA0006.jpg','rb') as r:
    with open('image2.jpg','wb') as w:
        w.write(r.read())

# %%
with open('/home/shreyansh/Pictures/IMG_20200919_131530_715.jpg','rb') as read_binary:
    with open('shreyansh_car.jpg','wb') as write_binary:
        write_binary.write(read_binary.read())

# %%
with open('/home/shreyansh/sql query/revise.sql','a') as write_file:
    write_file.write(input('enter: '))
# Out:
# enter: /* nothing more to add ,just a try */

# %%
with open('/home/shreyansh/sql query/insert data into table.sql','a') as append_file:
    append_file.write(input('enter data into table: '))
# Out:
# enter data into table: select * from employee;

# %%
a=int(input('enter the number data you want to insert: '))
with open('/home/shreyansh/sql query/insert data into table.sql','a') as append_file:
    for i in range(a):
        append_file.write(input('enter: '))
# Out:
# enter the number data you want to insert: 3
# enter: insert into employee values(2,'sneha','f',21,5000,'engineer');
# enter: insert into employee values(2,'ravi','m',22,3000,'react module');
# enter: insert into employee values(3,'rashika','f',23,4000,'data analyst');
